# %%
from google.colab import drive
import os
CODE_PATH='/content/drive/My Drive/TCC/Codes/Codigos Atualizados'
DATA_PATH = '/content/drive/My Drive/TCC/EMG_Database/'
drive.mount('/content/drive')
if not os.getcwd() == CODE_PATH:
  os.chdir(CODE_PATH)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
from dataset import Dataset
import os
import time
# Out:
# Using TensorFlow backend.

# %%
#from dataset import load_data_and_save_windows
from preprocessing import envelope, band_pass, dwt_filter
import os
from os.path import join
import numpy as np
from preprocessing import envelope

def create_dir(dirpath):
  if not os.path.exists(dirpath):
    os.mkdir(dirpath)
  
first_time = time.time()
path = join(DATA_PATH, "Windows_Files")
strides = [128, 256, 256, 512]
windows_sizes = [2**8, 2**9, 2**10, 2**11]
for subject in range(33, 41):

  
  first_suject_time = time.time()
  
    
  print(f"SUBJECT {subject}")
  data = None

  for use_envelope in ["enveloped","raw"]:
    for pure_samples in ["pure","nonpure"]:
      for window_size, stride in zip(windows_sizes, strides):
        start_iter_time = time.time()
        joined_path = join(path, use_envelope, pure_samples, f"{window_size}_{stride}")
        try:
          os.makedirs(joined_path)
        except:
          pass
        get_dataset_kws = dict(window_size=window_size,
                               stride=stride,
                               pure_samples=True if pure_samples=="pure" else False,
#                                processing_func=envelope if use_envelope=="enveloped" else None,
                               save_memory=True)
        if not (os.path.isfile(join(joined_path, f"data_{subject}.npy")) and os.path.isfile(join(joined_path, f"labels_{subject}.npy")) and os.path.isfile(join(joined_path, f"ids_{subject}.npy"))):

          if data==None:
              data = Dataset(DATA_PATH)
              data.get_data(subjects=[subject], verbose=0)
              data[subject].emg = band_pass(data[subject].emg)
              data[subject].emg = dwt_filter(data[subject].emg)

              raw_emg = data[subject].emg
              enveloped_emg = envelope(data[subject].emg)
          
          if use_envelope == "enveloped":
            data[subject].emg = enveloped_emg
          else:
            data[subject].emg = raw_emg
            
          windows, labels, ids = data.get_dataset(**get_dataset_kws)

          np.save(join(joined_path, f"data_{subject}.npy"), windows)
          np.save(join(joined_path, f"labels_{subject}.npy"), labels)
          np.save(join(joined_path, f"ids_{subject}.npy"), ids)
          print(f"TIME {use_envelope.upper()} {pure_samples.upper()} {window_size}: {time.time()-start_iter_time}s")
        else:
          print(f"{use_envelope.upper()} {pure_samples.upper()} {window_size}: ALREADY EXISTS")
  data == None
  print(f"SUBJECT {subject} TIME: {time.time()-first_suject_time}s")
print(f"TOTAL TIME: {time.time()-first_time}s")
# Out:
# SUBJECT 33
# Acessing  /content/drive/My Drive/TCC/EMG_Database/DB2_s33.zip
# TIME ENVELOPED PURE 256: 36.06762409210205s
# TIME ENVELOPED PURE 512: 7.306530237197876s
# TIME ENVELOPED PURE 1024: 63.198410749435425s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-f45d8028170f> in <module>()
#      54           windows, labels, ids = data.get_dataset(**get_dataset_kws)
#      55
# ---> 56           np.save(join(joined_path, f"data_{subject}.npy"), windows)
#      57           np.save(join(joined_path, f"labels_{subject}.npy"), labels)
#      58           np.save(join(joined_path, f"ids_{subject}.npy"), ids)
#
# /usr/local/lib/python3.6/dist-packages/numpy/lib/npyio.py in save(file, arr, allow_pickle, fix_imports)
#     534         arr = np.asanyarray(arr)
#     535         format.write_array(fid, arr, allow_pickle=allow_pickle,
# ...

# %%
google-drive-ocamlfuse -cc
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-290430265100> in <module>()
# ----> 1 google-drive-ocamlfuse -cc
#
# NameError: name 'google' is not defined

# %%
ls "/content/drive/My Drive/TCC/EMG_Database/Windows_Files/enveloped/nonpure/2048_512"
# Out:
# ls: cannot access '/content/drive/My Drive/TCC/EMG_Database/Windows_Files/enveloped/nonpure/2048_512': No such file or directory

# %%
# IME ENVELOPED NONPURE 2048: 77.89402031898499s
joined_path = join(path, "enveloped", "nonpure", "2048_512")
print(joined_path)
subject=3
(not os.path.isfile(join(joined_path, f"data_{subject}.npy"))) or (not os.path.isfile(join(joined_path, f"labels_{subject}.npy"))) or (not os.path.isfile(join(joined_path, f"ids_{subject}.npy")))
# Out:
# /content/drive/My Drive/TCC/EMG_Database/Windows_Files/enveloped/nonpure/2048_512
# True

# %%
# !df -h ./
# Out:
# Filesystem      Size  Used Avail Use% Mounted on
# drive            49G   29G   21G  60% /content/drive

# %%
ls "/content/drive/My Drive/TCC/Emg_Database"
# Out:
# ls: cannot access '/content/drive/My Drive/TCC/Emg_Database': No such file or directory

# %%
del data
# Out:
# The history saving thread hit an unexpected error (OperationalError('database or disk is full',)).History will not be written to the database.

# %%
SUBJECT 1
Acessing  /content/drive/My Drive/TCC/EMG_Database/DB2_s1.zip
TIME ENVELOPED PURE 256: 4.567648887634277s
TIME ENVELOPED PURE 512: 26.58745574951172s
TIME ENVELOPED PURE 1024: 47.061676025390625s
TIME ENVELOPED PURE 2048: 101.68096017837524s
TIME ENVELOPED NONPURE 256: 32.892449617385864s
TIME ENVELOPED NONPURE 512: 41.53696060180664s
TIME ENVELOPED NONPURE 1024: 60.866764068603516s
TIME ENVELOPED NONPURE 2048: 147.87301015853882s
TIME RAW PURE 256: 21.254287719726562s
TIME RAW PURE 512: 39.54162836074829s
TIME RAW PURE 1024: 59.28420639038086s
TIME RAW PURE 2048: 103.23901891708374s
TIME RAW NONPURE 256: 30.96530294418335s
TIME RAW NONPURE 512: 37.639283418655396s
TIME RAW NONPURE 1024: 70.61486196517944s
TIME RAW NONPURE 2048: 131.8527762889862s
SUBJECT 1 TIME: 984.6271262168884s
SUBJECT 2
Acessing  /content/drive/My Drive/TCC/EMG_Database/DB2_s2.zip
TIME ENVELOPED PURE 256: 12.84142255783081s
TIME ENVELOPED PURE 512: 31.508050680160522s
TIME ENVELOPED PURE 1024: 46.700549840927124s
TIME ENVELOPED PURE 2048: 113.81540775299072s
TIME ENVELOPED NONPURE 256: 35.85837769508362s
TIME ENVELOPED NONPURE 512: 33.57855439186096s
TIME ENVELOPED NONPURE 1024: 67.24379348754883s
TIME ENVELOPED NONPURE 2048: 133.22774863243103s
TIME RAW PURE 256: 33.3907744884491s
TIME RAW PURE 512: 23.569374561309814s
TIME RAW PURE 1024: 68.00304985046387s
TIME RAW PURE 2048: 103.0586724281311s
TIME RAW NONPURE 256: 32.34219789505005s
TIME RAW NONPURE 512: 34.78792357444763s
TIME RAW NONPURE 1024: 65.02897524833679s
TIME RAW NONPURE 2048: 136.25861191749573s
SUBJECT 2 TIME: 1023.6104221343994s
SUBJECT 3
Acessing  /content/drive/My Drive/TCC/EMG_Database/DB2_s3.zip
TIME ENVELOPED PURE 256: 4.992863893508911s
TIME ENVELOPED PURE 512: 31.215741634368896s
TIME ENVELOPED PURE 1024: 62.60731554031372s
TIME ENVELOPED PURE 2048: 101.57335209846497s
TIME ENVELOPED NONPURE 256: 28.4809250831604s
TIME ENVELOPED NONPURE 512: 39.860798835754395s
TIME ENVELOPED NONPURE 1024: 66.99076962471008s
TIME ENVELOPED NONPURE 2048: 133.9359679222107s
